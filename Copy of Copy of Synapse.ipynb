# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
from zipfile import ZipFile
from pathlib import Path
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# %pwd
path=Path("/content/drive/MyDrive/Rock identification on lunar surface/Rock identification on lunar surface.zip")

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pwd
# Out:
# '/content'

# %%
path=Path("/content/drive/MyDrive/Rock identification on lunar surface/Rock identification on lunar surface.zip")

# %%
with ZipFile(path,'r') as zip_file:
  [print(i) for i in zip_file.namelist()]
# Out:
# Streaming output truncated to the last 5000 lines.
# DataSet/Train Images/Train Images/Small/ground1002.png
# DataSet/Train Images/Train Images/Small/ground1003.png
# DataSet/Train Images/Train Images/Small/ground1004.png
# DataSet/Train Images/Train Images/Small/ground1005.png
# DataSet/Train Images/Train Images/Small/ground1006.png
# DataSet/Train Images/Train Images/Small/ground1007.png
# DataSet/Train Images/Train Images/Small/ground1008.png
# DataSet/Train Images/Train Images/Small/ground1009.png
# DataSet/Train Images/Train Images/Small/ground1010.png
# DataSet/Train Images/Train Images/Small/ground1011.png
# DataSet/Train Images/Train Images/Small/ground1012.png
# DataSet/Train Images/Train Images/Small/ground1013.png
# DataSet/Train Images/Train Images/Small/ground1014.png
# DataSet/Train Images/Train Images/Small/ground1015.png
# DataSet/Train Images/Train Images/Small/ground1016.png
# DataSet/Train Images/Train Images/Small/ground1017.png
# DataSet/Train Images/Train Images/Small/ground1018.png
# DataSet/Train Images/Train Images/Small/ground1019.png
# DataSet/Train Images/Train Images/Small/ground1020.png
# DataSet/Train Images/Train Images/Small/ground1021.png
# DataSet/Train Images/Train Images/Small/ground1022.png
# DataSet/Train Images/Train Images/Small/ground1023.png
# DataSet/Train Images/Train Images/Small/ground1024.png
# DataSet/Train Images/Train Images/Small/ground1025.png
# DataSet/Train Images/Train Images/Small/ground1026.png
# DataSet/Train Images/Train Images/Small/ground1027.png
# DataSet/Train Images/Train Images/Small/ground1028.png
# DataSet/Train Images/Train Images/Small/ground1029.png
# DataSet/Train Images/Train Images/Small/ground1030.png
# DataSet/Train Images/Train Images/Small/ground1031.png
# DataSet/Train Images/Train Images/Small/ground1032.png
# DataSet/Train Images/Train Images/Small/ground1033.png
# DataSet/Train Images/Train Images/Small/ground1034.png
# DataSet/Train Images/Train Images/Small/ground1035.png
# DataSet/Train Images/Train Images/Small/ground1036.png
# DataSet/Train Images/Train Images/Small/ground1037.png
# DataSet/Train Images/Train Images/Small/ground1038.png
# DataSet/Train Images/Train Images/Small/ground1039.png
# DataSet/Train Images/Train Images/Small/ground1040.png
# DataSet/Train Images/Train Images/Small/ground1041.png
# DataSet/Train Images/Train Images/Small/ground1042.png
# DataSet/Train Images/Train Images/Small/ground1043.png
# DataSet/Train Images/Train Images/Small/ground1044.png
# DataSet/Train Images/Train Images/Small/ground1045.png
# DataSet/Train Images/Train Images/Small/ground1046.png
# DataSet/Train Images/Train Images/Small/ground1047.png
# DataSet/Train Images/Train Images/Small/ground1048.png
# DataSet/Train Images/Train Images/Small/ground1049.png
# DataSet/Train Images/Train Images/Small/ground1050.png
# DataSet/Train Images/Train Images/Small/ground1051.png
# DataSet/Train Images/Train Images/Small/ground1863.png
# DataSet/Train Images/Train Images/Small/ground1864.png
# DataSet/Train Images/Train Images/Small/ground1865.png
# DataSet/Train Images/Train Images/Small/ground1866.png
# DataSet/Train Images/Train Images/Small/ground1867.png
# DataSet/Train Images/Train Images/Small/ground1868.png
# DataSet/Train Images/Train Images/Small/ground1869.png
# DataSet/Train Images/Train Images/Small/ground1870.png
# DataSet/Train Images/Train Images/Small/ground1871.png
# DataSet/Train Images/Train Images/Small/ground1872.png
# ...
# DataSet/Train Images/Train Images/Small/ground5710.png
# DataSet/Train Images/Train Images/Small/ground5711.png
# DataSet/Train Images/Train Images/Small/ground5712.png
# DataSet/Train Images/Train Images/Small/ground5713.png
# DataSet/Train Images/Train Images/Small/ground5714.png
# DataSet/Train Images/Train Images/Small/ground5715.png
# DataSet/Train Images/Train Images/Small/ground5716.png
# DataSet/Train Images/Train Images/Small/ground5717.png
# DataSet/Train Images/Train Images/Small/ground5718.png
# DataSet/Train Images/Train Images/Small/ground5719.png
# DataSet/Train Images/Train Images/Small/ground5720.png
# DataSet/Train Images/Train Images/Small/ground5721.png
# DataSet/Train Images/Train Images/Small/ground5722.png
# DataSet/Train Images/Train Images/Small/ground5723.png
# DataSet/Train Images/Train Images/Small/ground5724.png
# DataSet/Train Images/Train Images/Small/ground5725.png
# DataSet/Train Images/Train Images/Small/ground5726.png
# DataSet/Train Images/Train Images/Small/ground5727.png
# DataSet/Train Images/Train Images/Small/ground5728.png
# DataSet/Train Images/Train Images/Small/ground5729.png
# DataSet/Train Images/Train Images/Small/ground5730.png
# DataSet/Train Images/Train Images/Small/ground5731.png
# DataSet/Train Images/Train Images/Small/ground5732.png
# DataSet/Train Images/Train Images/Small/ground5733.png
# DataSet/Train Images/Train Images/Small/ground5734.png
# DataSet/Train Images/Train Images/Small/ground5735.png
# DataSet/Train Images/Train Images/Small/ground5736.png
# DataSet/Train Images/Train Images/Small/ground5737.png
# DataSet/Train Images/Train Images/Small/ground5738.png
# DataSet/Train Images/Train Images/Small/ground5739.png
# DataSet/Train Images/Train Images/Small/ground5740.png
# DataSet/Train Images/Train Images/Small/ground5741.png
# DataSet/Train Images/Train Images/Small/ground5742.png
# DataSet/Train Images/Train Images/Small/ground5743.png
# DataSet/Train Images/Train Images/Small/ground5744.png
# DataSet/Train Images/Train Images/Small/ground5745.png
# DataSet/Train Images/Train Images/Small/ground5746.png
# DataSet/Train Images/Train Images/Small/ground5747.png
# DataSet/Train Images/Train Images/Small/ground5748.png
# DataSet/Train Images/Train Images/Small/ground5749.png
# DataSet/Train Images/Train Images/Small/ground5750.png
# DataSet/Train Images/Train Images/Small/ground5751.png
# DataSet/Train Images/Train Images/Small/ground5752.png
# DataSet/Train Images/Train Images/Small/ground5753.png
# DataSet/Train Images/Train Images/Small/ground5754.png
# DataSet/Train Images/Train Images/Small/ground5755.png
# DataSet/Train Images/Train Images/Small/ground5756.png
# DataSet/Train Images/Train Images/Small/ground5757.png
# DataSet/Train Images/Train Images/Small/ground5758.png
# DataSet/Train Images/Train Images/Small/ground5759.png
# DataSet/Train Images/Train Images/Small/ground5760.png
# DataSet/Train Images/Train Images/Small/ground5761.png
# DataSet/Train Images/Train Images/Small/ground5762.png
# DataSet/Train Images/Train Images/Small/ground5763.png
# DataSet/Train Images/Train Images/Small/ground5764.png
# DataSet/Train Images/Train Images/Small/ground5765.png
# DataSet/Train Images/Train Images/Small/ground5766.png
# DataSet/Train Images/Train Images/Small/ground5767.png
# DataSet/Train Images/Train Images/Small/ground5768.png
# DataSet/Train Images/Train Images/Small/ground5769.png
# DataSet/Train Images/Train Images/Small/ground5770.png
# DataSet/Train Images/Train Images/Small/ground5771.png
# DataSet/Train Images/Train Images/Small/ground5772.png
# DataSet/Train Images/Train Images/Small/ground5773.png
# DataSet/Train Images/Train Images/Small/ground5774.png
# DataSet/Train Images/Train Images/Small/ground5775.png
# DataSet/Train Images/Train Images/Small/ground5776.png
# DataSet/Train Images/Train Images/Small/ground5777.png
# DataSet/Train Images/Train Images/Small/ground5778.png
# DataSet/Train Images/Train Images/Small/ground5779.png
# DataSet/Train Images/Train Images/Small/ground5780.png
# DataSet/Train Images/Train Images/Small/ground5781.png
# DataSet/Train Images/Train Images/Small/ground5782.png
# DataSet/Train Images/Train Images/Small/ground5783.png
# DataSet/Train Images/Train Images/Small/ground5784.png
# DataSet/Train Images/Train Images/Small/ground5785.png
# DataSet/Train Images/Train Images/Small/ground5786.png
# DataSet/Train Images/Train Images/Small/ground5787.png
# DataSet/Train Images/Train Images/Small/ground5788.png
# DataSet/Train Images/Train Images/Small/ground5789.png
# DataSet/Train Images/Train Images/Small/ground5790.png
# DataSet/Train Images/Train Images/Small/ground5791.png
# DataSet/Train Images/Train Images/Small/ground5792.png
# DataSet/Train Images/Train Images/Small/ground5793.png
# DataSet/Train Images/Train Images/Small/ground5794.png
# DataSet/Train Images/Train Images/Small/ground5795.png
# DataSet/Train Images/Train Images/Small/ground5796.png
# DataSet/Train Images/Train Images/Small/ground5797.png
# DataSet/Train Images/Train Images/Small/ground5798.png
# DataSet/Train Images/Train Images/Small/ground5799.png
# DataSet/Train Images/Train Images/Small/ground5800.png
# DataSet/Train Images/Train Images/Small/ground5801.png
# DataSet/Train Images/Train Images/Small/ground5802.png
# DataSet/Train Images/Train Images/Small/ground5803.png
# DataSet/Train Images/Train Images/Small/ground5804.png
# DataSet/Train Images/Train Images/Small/ground5805.png
# DataSet/Train Images/Train Images/Small/ground5806.png
# DataSet/Train Images/Train Images/Small/ground5807.png
# DataSet/Train Images/Train Images/Small/ground5808.png
# DataSet/Train Images/Train Images/Small/ground5809.png
# DataSet/Train Images/Train Images/Small/ground5810.png
# DataSet/Train Images/Train Images/Small/ground5811.png
# DataSet/Train Images/Train Images/Small/ground5812.png
# DataSet/Train Images/Train Images/Small/ground5813.png
# DataSet/Train Images/Train Images/Small/ground5814.png
# DataSet/Train Images/Train Images/Small/ground5815.png
# DataSet/Train Images/Train Images/Small/ground5816.png
# DataSet/Train Images/Train Images/Small/ground5817.png
# DataSet/Train Images/Train Images/Small/ground5818.png
# DataSet/Train Images/Train Images/Small/ground5819.png
# DataSet/Train Images/Train Images/Small/ground5820.png
# DataSet/Train Images/Train Images/Small/ground5821.png
# DataSet/Train Images/Train Images/Small/ground5822.png
# DataSet/Train Images/Train Images/Small/ground5823.png
# DataSet/Train Images/Train Images/Small/ground5824.png
# DataSet/Train Images/Train Images/Small/ground5825.png
# DataSet/Train Images/Train Images/Small/ground5826.png
# DataSet/Train Images/Train Images/Small/ground5827.png
# DataSet/Train Images/Train Images/Small/ground5828.png
# DataSet/Train Images/Train Images/Small/ground5829.png
# DataSet/Train Images/Train Images/Small/ground5830.png
# DataSet/Train Images/Train Images/Small/ground5831.png
# DataSet/Train Images/Train Images/Small/ground5832.png
# DataSet/Train Images/Train Images/Small/ground5833.png
# DataSet/Train Images/Train Images/Small/ground5834.png
# DataSet/Train Images/Train Images/Small/ground5835.png
# DataSet/Train Images/Train Images/Small/ground5836.png
# DataSet/Train Images/Train Images/Small/ground5837.png
# DataSet/Train Images/Train Images/Small/ground5838.png
# DataSet/Train Images/Train Images/Small/ground5839.png
# DataSet/Train Images/Train Images/Small/ground5840.png
# DataSet/Train Images/Train Images/Small/ground5841.png
# DataSet/Train Images/Train Images/Small/ground5842.png
# DataSet/Train Images/Train Images/Small/ground5843.png
# DataSet/Train Images/Train Images/Small/ground5844.png
# DataSet/Train Images/Train Images/Small/ground5845.png
# DataSet/Train Images/Train Images/Small/ground5846.png
# DataSet/Train Images/Train Images/Small/ground5847.png
# DataSet/Train Images/Train Images/Small/ground5848.png
# DataSet/Train Images/Train Images/Small/ground5849.png
# DataSet/Train Images/Train Images/Small/ground5850.png
# DataSet/Train Images/Train Images/Small/ground5851.png
# DataSet/Train Images/Train Images/Small/ground5852.png
# DataSet/Train Images/Train Images/Small/ground5853.png
# DataSet/Train Images/Train Images/Small/ground5854.png
# DataSet/Train Images/Train Images/Small/ground5855.png
# DataSet/Train Images/Train Images/Small/ground5856.png
# DataSet/Train Images/Train Images/Small/ground5857.png
# DataSet/Train Images/Train Images/Small/ground5858.png
# DataSet/Train Images/Train Images/Small/ground5859.png
# DataSet/Train Images/Train Images/Small/ground5860.png
# DataSet/Train Images/Train Images/Small/ground5861.png
# DataSet/Train Images/Train Images/Small/ground5862.png
# DataSet/Train Images/Train Images/Small/ground5863.png
# DataSet/Train Images/Train Images/Small/ground5864.png
# DataSet/Train Images/Train Images/Small/ground5865.png
# DataSet/Train Images/Train Images/Small/ground5866.png
# DataSet/Train Images/Train Images/Small/ground5867.png
# DataSet/Train Images/Train Images/Small/ground5868.png
# DataSet/Train Images/Train Images/Small/ground5869.png
# DataSet/Train Images/Train Images/Small/ground5870.png
# DataSet/Train Images/Train Images/Small/ground5871.png
# DataSet/Train Images/Train Images/Small/ground5872.png
# DataSet/Train Images/Train Images/Small/ground5873.png
# DataSet/Train Images/Train Images/Small/ground5874.png
# DataSet/Train Images/Train Images/Small/ground5875.png
# DataSet/Train Images/Train Images/Small/ground5876.png
# DataSet/Train Images/Train Images/Small/ground5877.png
# DataSet/Train Images/Train Images/Small/ground5878.png
# DataSet/Train Images/Train Images/Small/ground5879.png
# DataSet/Train Images/Train Images/Small/ground5880.png
# DataSet/Train Images/Train Images/Small/ground5881.png
# DataSet/Train Images/Train Images/Small/ground5882.png
# DataSet/Train Images/Train Images/Small/ground5883.png
# DataSet/Train Images/Train Images/Small/ground5884.png
# DataSet/Train Images/Train Images/Small/ground5885.png
# DataSet/Train Images/Train Images/Small/ground5886.png
# DataSet/Train Images/Train Images/Small/ground5887.png
# DataSet/Train Images/Train Images/Small/ground5888.png
# DataSet/Train Images/Train Images/Small/ground5889.png
# DataSet/Train Images/Train Images/Small/ground5890.png
# DataSet/Train Images/Train Images/Small/ground5891.png
# DataSet/Train Images/Train Images/Small/ground5892.png
# DataSet/Train Images/Train Images/Small/ground5893.png
# DataSet/Train Images/Train Images/Small/ground5894.png
# DataSet/Train Images/Train Images/Small/ground5895.png
# DataSet/Train Images/Train Images/Small/ground5896.png
# DataSet/Train Images/Train Images/Small/ground5897.png
# DataSet/Train Images/Train Images/Small/ground5898.png
# DataSet/Train Images/Train Images/Small/ground5899.png
# DataSet/Train Images/Train Images/Small/ground5900.png
# DataSet/Train Images/Train Images/Small/ground5901.png
# DataSet/Train Images/Train Images/Small/ground5902.png
# DataSet/Train Images/Train Images/Small/ground5903.png
# DataSet/Train Images/Train Images/Small/ground5904.png
# DataSet/Train Images/Train Images/Small/ground5905.png
# DataSet/Train Images/Train Images/Small/ground5906.png
# DataSet/Train Images/Train Images/Small/ground5907.png
# DataSet/Train Images/Train Images/Small/ground5908.png
# DataSet/Train Images/Train Images/Small/ground5909.png
# DataSet/Train Images/Train Images/Small/ground5910.png
# DataSet/Train Images/Train Images/Small/ground5911.png
# DataSet/Train Images/Train Images/Small/ground5912.png
# DataSet/Train Images/Train Images/Small/ground5913.png
# DataSet/Train Images/Train Images/Small/ground5914.png
# DataSet/Train Images/Train Images/Small/ground5915.png
# DataSet/Train Images/Train Images/Small/ground5916.png
# DataSet/Train Images/Train Images/Small/ground5917.png
# DataSet/Train Images/Train Images/Small/ground5918.png
# DataSet/Train Images/Train Images/Small/ground5919.png
# DataSet/Train Images/Train Images/Small/ground5920.png
# DataSet/Train Images/Train Images/Small/ground5921.png
# DataSet/Train Images/Train Images/Small/ground5922.png
# DataSet/Train Images/Train Images/Small/ground5923.png
# DataSet/Train Images/Train Images/Small/ground5924.png
# DataSet/Train Images/Train Images/Small/ground5925.png
# DataSet/Train Images/Train Images/Small/ground5926.png
# DataSet/Train Images/Train Images/Small/ground5927.png
# DataSet/Train Images/Train Images/Small/ground5928.png
# DataSet/Train Images/Train Images/Small/ground5929.png
# DataSet/Train Images/Train Images/Small/ground5930.png
# DataSet/Train Images/Train Images/Small/ground5931.png
# DataSet/Train Images/Train Images/Small/ground5932.png
# DataSet/Train Images/Train Images/Small/ground5933.png
# DataSet/Train Images/Train Images/Small/ground5934.png
# DataSet/Train Images/Train Images/Small/ground5935.png
# DataSet/Train Images/Train Images/Small/ground5936.png
# DataSet/Train Images/Train Images/Small/ground5937.png
# DataSet/Train Images/Train Images/Small/ground5938.png
# DataSet/Train Images/Train Images/Small/ground5939.png
# DataSet/Train Images/Train Images/Small/ground5940.png
# DataSet/Train Images/Train Images/Small/ground5941.png
# DataSet/Train Images/Train Images/Small/ground5942.png
# DataSet/Train Images/Train Images/Small/ground5943.png
# DataSet/Train Images/Train Images/Small/ground5944.png
# DataSet/Train Images/Train Images/Small/ground5945.png
# DataSet/Train Images/Train Images/Small/ground5946.png
# DataSet/Train Images/Train Images/Small/ground5947.png
# DataSet/Train Images/Train Images/Small/ground5948.png
# DataSet/Train Images/Train Images/Small/ground5949.png
# DataSet/Train Images/Train Images/Small/ground5950.png
# DataSet/Train Images/Train Images/Small/ground5951.png
# DataSet/Train Images/Train Images/Small/ground5952.png
# DataSet/Train Images/Train Images/Small/ground5953.png
# DataSet/Train Images/Train Images/Small/ground5954.png
# DataSet/Train Images/Train Images/Small/ground5955.png
# DataSet/Train Images/Train Images/Small/ground5956.png
# DataSet/Train Images/Train Images/Small/ground5957.png
# DataSet/Train Images/Train Images/Small/ground5958.png
# DataSet/Train Images/Train Images/Small/ground5959.png
# DataSet/Train Images/Train Images/Small/ground5960.png
# DataSet/Train Images/Train Images/Small/ground5961.png
# DataSet/Train Images/Train Images/Small/ground5962.png
# DataSet/Train Images/Train Images/Small/ground5963.png
# DataSet/Train Images/Train Images/Small/ground5964.png
# DataSet/Train Images/Train Images/Small/ground5965.png
# DataSet/Train Images/Train Images/Small/ground5966.png
# DataSet/Train Images/Train Images/Small/ground5967.png
# DataSet/Train Images/Train Images/Small/ground5968.png
# DataSet/Train Images/Train Images/Small/ground5969.png
# DataSet/Train Images/Train Images/Small/ground5970.png
# DataSet/Train Images/Train Images/Small/ground5971.png
# DataSet/Train Images/Train Images/Small/ground5972.png
# DataSet/Train Images/Train Images/Small/ground5973.png
# DataSet/Train Images/Train Images/Small/ground5974.png
# DataSet/Train Images/Train Images/Small/ground5975.png
# DataSet/Train Images/Train Images/Small/ground5976.png
# DataSet/Train Images/Train Images/Small/ground5977.png
# DataSet/Train Images/Train Images/Small/ground5978.png
# DataSet/Train Images/Train Images/Small/ground5979.png
# DataSet/Train Images/Train Images/Small/ground5980.png
# DataSet/Train Images/Train Images/Small/ground5981.png
# DataSet/Train Images/Train Images/Small/ground5982.png
# DataSet/Train Images/Train Images/Small/ground5983.png
# DataSet/Train Images/Train Images/Small/ground5984.png
# DataSet/Train Images/Train Images/Small/ground5985.png
# DataSet/Train Images/Train Images/Small/ground5986.png
# DataSet/Train Images/Train Images/Small/ground5987.png
# DataSet/Train Images/Train Images/Small/ground5988.png
# DataSet/Train Images/Train Images/Small/ground5989.png
# DataSet/Train Images/Train Images/Small/ground5990.png
# DataSet/Train Images/Train Images/Small/ground5991.png
# DataSet/Train Images/Train Images/Small/ground5992.png
# DataSet/Train Images/Train Images/Small/ground5993.png
# DataSet/Train Images/Train Images/Small/ground5994.png
# DataSet/Train Images/Train Images/Small/ground5995.png
# DataSet/Train Images/Train Images/Small/ground5996.png
# DataSet/Train Images/Train Images/Small/ground5997.png
# DataSet/Train Images/Train Images/Small/ground5998.png
# DataSet/Train Images/Train Images/Small/ground5999.png
# DataSet/test.csv
# DataSet/train.csv

# %%
file_info=zip_file.getinfo('DataSet/Train Images/Train Images/Small/ground5448.png')

# %%
print(file_info.filename)
print(file_info.file_size)
print(file_info.date_time)
print(file_info.compress_size)
print(file_info.compress_type)
# Out:
# DataSet/Train Images/Train Images/Small/ground5448.png
# 66884
# (2019, 10, 1, 9, 57, 20)
# 66469
# 8

# %%
source_path=Path('/content/drive/MyDrive/Rock identification on lunar surface/Rock identification on lunar surface.zip')
source_path.exists()
# Out:
# True

# %%
destination_path=Path("drive/MyDrive/test")
destination_path.exists()
# Out:
# True

# %%
with ZipFile(source_path) as zip_file:
  zip_file.extractall(destination_path)

# %%
tr_l_path = '/content/drive/MyDrive/test/DataSet/train.csv'
tr_s_path = '/content/drive/MyDrive/test/DataSet/train.csv'
te_path = '/content/drive/MyDrive/test/DataSet/test.csv'

# Load CSV files into DataFrames
tr_l_df = pd.read_csv(tr_l_path)
tr_s_df = pd.read_csv(tr_s_path)
te_df = pd.read_csv(te_path)

# Display the number of records in each DataFrame
print("\n -> Number of records in train large:", len(tr_l_df))
print("\n -> Number of records in train small:", len(tr_s_df))
print("\n -> Number of records in test:", len(te_df))
tr_s_path = '/content/drive/MyDrive/test/DataSet/train.csv'
te_path = '/content/drive/MyDrive/test/DataSet/test.csv'

# Load CSV files into DataFrames
tr_l_df = pd.read_csv(tr_l_path)
tr_s_df = pd.read_csv(tr_s_path)
te_df = pd.read_csv(te_path)

# Display the number of records in each DataFrame
print("\n -> Number of records in train large:", len(tr_l_df))
print("\n -> Number of records in train small:", len(tr_s_df))
print("\n -> Number of records in test:", len(te_df))
# Out:
#  -> Number of records in train large: 11998
#
#  -> Number of records in train small: 11998
#
#  -> Number of records in test: 7534
#
#  -> Number of records in train large: 11998
#
#  -> Number of records in train small: 11998
#
#  -> Number of records in test: 7534

# %%
import os

tr_l_list = os.listdir('/content/drive/MyDrive/test/DataSet/Train Images/Train Images/Large')

tr_s_list = os.listdir('/content/drive/MyDrive/test/DataSet/Train Images/Train Images/Small')

te_list = os.listdir('/content/drive/MyDrive/test/DataSet/Test Images/Test Images')

print("\n -> Number of images in train large:", len(tr_l_list))
print("\n -> Number of images in train small:", len(tr_s_list))
print("\n -> Number of images in test:", len(te_list))
# Out:
#  -> Number of images in train large: 5999
#
#  -> Number of images in train small: 5999
#
#  -> Number of images in test: 7537

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread("/content/drive/MyDrive/test/DataSet/Train Images/Train Images/Large/clean0985.png")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=720x480>

# %%
from google.colab.patches import cv2_imshow
import cv2

# Specify the path to the directory containing the images
directory_path = "/content/drive/MyDrive/test/DataSet/Train Images/Train Images/Large/"

# Specify the filenames of the 5 images you want to display
image_filenames = ["clean0985.png", "clean0986.png", "clean0987.png", "clean0988.png", "clean0989.png"]

# Loop through the image filenames and display each image
for filename in image_filenames:
    image_path = directory_path + filename
    img = cv2.imread(image_path)

    # Display the image
    cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=720x480>
# <PIL.Image.Image image mode=RGB size=720x480>
# <PIL.Image.Image image mode=RGB size=720x480>
# <PIL.Image.Image image mode=RGB size=720x480>
# <PIL.Image.Image image mode=RGB size=720x480>

# %%
df = pd.read_csv('/content/drive/MyDrive/test/DataSet/train.csv')

print("\n -> Displaying head of train dataframe.\n")

df.head()
# Out:
#  -> Displaying head of train dataframe.
#        Image_File  Class
# 0   clean2416.png  Large
# 1  ground4022.png  Small
# 2  ground0340.png  Small
# 3  ground2110.png  Small
# 4   clean1581.png  Large

# %%
print("\n -> Shape of train data:", df.shape)
print("\n -> Number of rows in train data:", df.shape[0])
print("\n -> Number of columns in train data:", df.shape[1])
print("\n -> Number of images in train data:", df.shape[0])
print("\n -> Number of images of class Large in train data:", df.Class.value_counts()[1])
print("\n -> Number of images of class Small in train data:", df.Class.value_counts()[0])
# Out:
#  -> Shape of train data: (11998, 2)
#
#  -> Number of rows in train data: 11998
#
#  -> Number of columns in train data: 2
#
#  -> Number of images in train data: 11998
#
#  -> Number of images of class Large in train data: 5999
#
#  -> Number of images of class Small in train data: 5999

# %%
print("\n -> Count of Large and Small class.\n")
print(df.Class.value_counts())
# Out:
#  -> Count of Large and Small class.
#
# Large    5999
# Small    5999
# Name: Class, dtype: int64

# %%
import seaborn as sns
# %matplotlib inline
print("\n -> Graphically visualzing count of Large and Small class.\n")

sns.countplot(df.Class)
plt.show()
# Out:
#  -> Graphically visualzing count of Large and Small class.

# %%
import keras

from keras.preprocessing.image import ImageDataGenerator

img_gen = ImageDataGenerator(rotation_range = 30,
                            width_shift_range = 0.1,
                            height_shift_range = 0.1,
                            rescale = 1/255,
                            zoom_range = 0.2)

# %%
print(" -> Original image from Train Large\n")

re = cv2.imread('/content/drive/MyDrive/test/DataSet/Train Images/Train Images/Large/'+tr_l_list[1])
re = cv2.cvtColor(re, cv2.COLOR_BGR2RGB)

plt.imshow(re)
plt.show()
# Out:
#  -> Original image from Train Large

# %%
print(" -> Generated image from Train Large\n")

re = cv2.imread('/content/drive/MyDrive/test/DataSet/Train Images/Train Images/Large/clean0001.png')
re = cv2.cvtColor(re, cv2.COLOR_BGR2RGB)

plt.imshow(re)
plt.show()
# Out:
#  -> Generated image from Train Large

# %% [markdown]
# OBSERVATION

# %%
print("\n -> Viewing number of classes in train data\n")

print(img_gen.flow_from_directory('/content/drive/MyDrive/test/DataSet/Train Images/Train Images'))
# Out:
#  -> Viewing number of classes in train data
#
# Found 11998 images belonging to 2 classes.
# <keras.src.preprocessing.image.DirectoryIterator object at 0x7a56af43cfa0>

# %%
print("\n -> Shape of image:", re.shape)
print("\n -> Width of image:", re.shape[0])
print("\n -> Width of image:", re.shape[1])
print("\n -> Number of color channels of image:", re.shape[2])
# Out:
#  -> Shape of image: (480, 720, 3)
#
#  -> Width of image: 480
#
#  -> Width of image: 720
#
#  -> Number of color channels of image: 3

# %%
input_shape = (480, 480, 3)

# %%
from keras.models import Sequential, Model

from keras import regularizers

from keras.layers import Activation, Conv2D, MaxPool2D, Dropout, Dense, Flatten

# %%
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping

checkpoint_2 = ModelCheckpoint("lunar_model_2.h5", monitor = "train_loss", mode = "min",
                                save_best_only = True, verbose = 1)


earlystop_2 = EarlyStopping(monitor = 'train_loss', mode = "min", patience = 5,
                            verbose = 1, restore_best_weights = True)

tensorboard_2 = TensorBoard(log_dir = "drive/My Drive/Lunar Rock/lunar_graph_2",
                         histogram_freq = 0, batch_size = 500, write_graph = True,
                         write_grads = False, write_images = False, embeddings_freq = 0,
                         embeddings_layer_names = None, embeddings_metadata = None,
                         embeddings_data = None, update_freq = 'epoch')


callback_2 = [checkpoint_2, earlystop_2, tensorboard_2]

# %%
import warnings
warnings.filterwarnings('ignore')


model = Sequential()

model.add(Conv2D(filters = 128, kernel_size = (3,3), input_shape = input_shape, activation = 'relu', kernel_regularizer = regularizers.l2(0.01)))
model.add(MaxPool2D(pool_size = (2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(filters = 64, kernel_size = (3,3), input_shape = input_shape, activation = 'relu', kernel_regularizer = regularizers.l2(0.01)))
model.add(MaxPool2D(pool_size = (2,2)))
model.add(Dropout(0.3))


model.add(Conv2D(filters = 64, kernel_size = (3,3), input_shape = input_shape, activation = 'relu', kernel_regularizer = regularizers.l2(0.01)))
model.add(MaxPool2D(pool_size = (2,2)))
model.add(Dropout(0.3))

model.add(Flatten())

model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.3))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
import pydot_ng as pydot
from keras.utils import plot_model
from IPython.display import Image

plot_model(model, show_shapes = True, show_layer_names = True, to_file = '/content/drive/MyDrive/test/DataSet/Train Images/Train Images/Large/clean0001.png')

Image(retina = True, filename = '/content/drive/MyDrive/test/DataSet/Train Images/Train Images/Large/clean0001.png')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 478, 478, 128)     3584
#
#  max_pooling2d (MaxPooling2  (None, 239, 239, 128)     0
#  D)
#
#  dropout (Dropout)           (None, 239, 239, 128)     0
#
#  conv2d_1 (Conv2D)           (None, 237, 237, 64)      73792
#
#  max_pooling2d_1 (MaxPoolin  (None, 118, 118, 64)      0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 118, 118, 64)      0
#
#  conv2d_2 (Conv2D)           (None, 116, 116, 64)      36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 58, 58, 64)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 58, 58, 64)        0
#
#  flatten (Flatten)           (None, 215296)            0
#
#  dense (Dense)               (None, 128)               27558016
#
#  activation (Activation)     (None, 128)               0
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
#  activation_1 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 27672449 (105.56 MB)
# Trainable params: 27672449 (105.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
batch_size = 16

train_img_gen = img_gen.flow_from_directory(('/content/drive/MyDrive/test/DataSet/Train Images/Train Images'),
                                           target_size = input_shape[:2],
                                           batch_size = batch_size,
                                           class_mode = 'binary')
# Out:
# Found 11998 images belonging to 2 classes.

# %%
print("\n -> Class indices.\n")

print(train_img_gen.class_indices)
# Out:
#  -> Class indices.
#
# {'Large': 0, 'Small': 1}

# %%
import warnings
warnings.filterwarnings('ignore')

results = model.fit_generator(train_img_gen, epochs = 20, steps_per_epoch = 100, callbacks = callback_2)
# Out:
# Epoch 1/20
# 100/100 [==============================] - ETA: 0s - loss: 1.4433 - accuracy: 0.7481
# WARNING:tensorflow:Can save best model only with train_loss available, skipping.
# WARNING:tensorflow:Early stopping conditioned on metric `train_loss` which is not available. Available metrics are: loss,accuracy
# 100/100 [==============================] - 2907s 29s/step - loss: 1.4433 - accuracy: 0.7481
# Epoch 2/20
#  64/100 [==================>...........] - ETA: 18:34 - loss: 0.6979 - accuracy: 0.9189
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-121-635b29ab3bef> in <cell line: 4>()
#       2 warnings.filterwarnings('ignore')
#       3
# ----> 4 results = model.fit_generator(train_img_gen, epochs = 20, steps_per_epoch = 100, callbacks = callback_2)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2911             stacklevel=2,
#    2912         )
# -> 2913         return self.fit(
#    2914             generator,
#    2915             steps_per_epoch=steps_per_epoch,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1805                         ):
#    1806                             callbacks.on_train_batch_begin(step)
# -> 1807                             tmp_logs = self.train_function(iterator)
#    1808                             if data_handler.should_sync:
#    1809                                 context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     866       # In this case we have created variables on the first call, so we run the
#     867       # defunned version which is guaranteed to never create variables.
# --> 868       return tracing_compilation.call_function(
#     869           args, kwds, self._no_variable_creation_config
#     870       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
print("Original small image after resizing\n")

r = cv2.imread('/content/drive/MyDrive/test/DataSet/Train Images/Train Images/Small/ground0001.png')
r = cv2.cvtColor(r, cv2.COLOR_BGR2RGB)
r = cv2.resize(r, (480, 480))
r = np.expand_dims(r, axis = 0)
# Out:
# Original small image after resizing

# %%
test = pd.read_csv('/content/drive/MyDrive/test/DataSet/test.csv')

print("\n -> Displaying head of test data.\n")

test.head()
# Out:
#  -> Displaying head of test data.
#          Image_File  Class
# 0    lg 988 (1).png    NaN
# 1   lg 988 (10).png    NaN
# 2  lg 988 (100).png    NaN
# 3  lg 988 (101).png    NaN
# 4  lg 988 (102).png    NaN

# %%
print("\n -> Shape of test data:", test.shape)
print("\n -> Number of rows in test data:", test.shape[0])
print("\n -> Number of columns in test data:", test.shape[1])
print("\n -> Number of images in test data:", test.shape[0])
# Out:
#  -> Shape of test data: (7534, 2)
#
#  -> Number of rows in test data: 7534
#
#  -> Number of columns in test data: 2
#
#  -> Number of images in test data: 7534

# %%
print("First 10 images from test")
print('*'*35, '\n')

fig = plt.figure(figsize=(20,20))

read = cv2.imread('/content/drive/MyDrive/test/DataSet/Test Images/Test Images/lg 988 (1).png')
img = cv2.cvtColor(read, cv2.COLOR_BGR2RGB)
fig.add_subplot(5,2,1)
plt.imshow(img)

for i in range(2, 11):

    fig.add_subplot(5,2,i)

    read = cv2.imread('/content/drive/MyDrive/test/DataSet/Test Images/Test Images/lg 988 (1).png')
    img = cv2.cvtColor(read, cv2.COLOR_BGR2RGB)
    plt.imshow(img)

plt.show()
# Out:
# First 10 images from test
# ***********************************

# %%
test_files = np.array(test['Image_File'])

test_files[:5]
# Out:
# array(['lg 988 (1).png', 'lg 988 (10).png', 'lg 988 (100).png',
#        'lg 988 (101).png', 'lg 988 (102).png'], dtype=object)

# %%
import os

test_arr = []

for i in range(len(test_files)):

    file_path = os.path.join('/content/drive/MyDrive/test/DataSet/Test Images/Test Images', test_files[i])
    t = cv2.imread(file_path)
    t = cv2.cvtColor(t, cv2.COLOR_BGR2RGB)
    t = cv2.resize(t, (480, 480))
    t = np.expand_dims(t, axis = 0)
    t = np.array(t)
    test_arr.append(t)

# %%
predict = []

for i in range(len(test_arr)):

    pred = model.predict(test_arr[i])
    predict.append(pred)

# %%
test.head()
# Out:
#          Image_File  Class
# 0    lg 988 (1).png    NaN
# 1   lg 988 (10).png    NaN
# 2  lg 988 (100).png    NaN
# 3  lg 988 (101).png    NaN
# 4  lg 988 (102).png    NaN

# %%
pred_list = []

for i in range(len(predict)):

    pred = int(predict[i][0][0])
    pred_list.append(pred)

# %%
print(f"Length of test_arr: {len(test_arr)}")
print(f"Length of test: {len(test)}")
# Out:
# Length of test_arr: 7534
# Length of test: 7534

# %%
print("\n -> Class indices.\n")
train_img_gen.class_indices
# Out:
#  -> Class indices.
# {'Large': 0, 'Small': 1}

# %%
test['Class'] = test['Class'].apply(lambda x: 'Large' if x == 0 else 'Small')

# %%
# Load unseen images
unseen_files = ['/content/drive/MyDrive/test/DataSet/Test Images/Test Images/lg 988 (1).png']
unseen_arr = []
for file in unseen_files:
    img = cv2.imread(file)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (480, 480))
    img = np.expand_dims(img, axis=0)
    unseen_arr.append(img)

# Predict the class of unseen images
unseen_pred = []
for arr in unseen_arr:
    pred = model.predict(arr)
    unseen_pred.append(pred[0][0])

# Add predictions to a new DataFrame
unseen_df = pd.DataFrame(unseen_pred, columns=['Probability'])
unseen_df['Filename'] = unseen_files

# Set the class label based on the predicted probability
unseen_df['Class'] = unseen_df['Probability'].apply(lambda x: 'Large' if x > 0.5 else 'Small')

# Append predictions to the existing test DataFrame
test = test.append(unseen_df, ignore_index=True)
# Out:
# 1/1 [==============================] - 1s 544ms/step

# %%
import cv2
import numpy as np

# Define the file name of the image to classify
file_name = '/content/drive/MyDrive/test/DataSet/Test Images/Test Images/lg 988 (1).png'

# Load and preprocess the image
img = cv2.imread(file_name)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (480, 480))
img = np.expand_dims(img, axis=0)
img = np.expand_dims(img, axis=-1)
img = np.squeeze(img, axis=-1)

# Predict the class of the image
predictions = model.predict(img)

# Map the predicted probability to a class label
class_label = 'Small' if predictions < 0.5 else 'Large'

# Print the result
print(f'The object in the image {file_name} is {class_label}')
# Out:
# 1/1 [==============================] - 1s 535ms/step
# The object in the image /content/drive/MyDrive/test/DataSet/Test Images/Test Images/lg 988 (1).png is Large

# %%
import cv2
import numpy as np

# Define the file name of the image to classify
file_name = '/content/drive/MyDrive/test/DataSet/Test Images/Test Images/lg 988 (126).png'

# Load and preprocess the image
img = cv2.imread(file_name)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (480, 480))
img = np.expand_dims(img, axis=0)
img = np.expand_dims(img, axis=-1)
img = np.squeeze(img, axis=-1)

# Predict the class of the image
predictions = model.predict(img)

# Map the predicted probability to a class label
class_label = 'Small' if predictions < 0.5 else 'Large'

# Print the result
print(f'The object in the image {file_name} is {class_label}')
# Out:
# 1/1 [==============================] - 0s 338ms/step
# The object in the image /content/drive/MyDrive/test/DataSet/Test Images/Test Images/lg 988 (126).png is Small

# %%
from sklearn.metrics import classification_report

# Get the true labels of the test images
true_labels = mnist.target

print(f'Length of true_labels: {len(true_labels)}')
print(f'Length of predictions: {len(predictions)}')
# Out:
# Length of true_labels: 70000
# Length of predictions: 1

# %%
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np

# %%
# Load the MNIST dataset
mnist = tf.keras.datasets.mnist

# Load the test images and labels
test_images, test_labels = mnist.load_data()[1]

# Normalize the test images
test_images = test_images / 255.0

# Modify the model to accept the input shape of the test images
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Make predictions on the test images
predictions = model.predict(test_images)

# Get the true labels of the test images
true_labels = test_labels

# Compute the precision, recall, and F1 score
precision = precision_score(true_labels, np.argmax(predictions, axis=1), average='weighted')
recall = recall_score(true_labels, np.argmax(predictions, axis=1), average='weighted')
f1 = f1_score(true_labels, np.argmax(predictions, axis=1), average='weighted')

# Print the precision, recall, and F1 score
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# 313/313 [==============================] - 4s 11ms/step
# Precision: 0.01884196997608151
# Recall: 0.1127
# F1 Score: 0.028961874857850706
